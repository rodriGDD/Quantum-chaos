# %%
from qutip import *
import math as math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import scipy as scipy
import matplotlib.animation as animation
from tqdm import tqdm
import sys
import matplotlib.gridspec as gridspec

# %% [markdown]
# Parámetros del sistema

# %%
w_0 = 0.5 # Frecuencia natural x>0
W_0 = 7 # Frecuencia natural x<0
amort = 0.125 # constante de amortiguamiento
f_0 = 0.25 # Amplitud de la fuerza por unidad de masa
m = 1 # masa del oscilador
N = 5 # Numero de fonones
w = [1.4] # frecuencia de la fuerza externa
X_0 = 5 # Condición inicial
n = np.size(w)

# %%
rep = n-1 # w para la que queremos las figuras

# %% [markdown]
# Frecuencia natural del oscilador

# %%
def W(x): # frecuecia angular
    return W_0 - (W_0-w_0)*np.heaviside(x,w_0)

# %% [markdown]
# Desarrollo del potencial en la base de autoestados del oscilador armónico cuántico

# %%
def U(x):
    return 0.5*m*x**2*W(x)**2

# %%
def autoest(n,x,conj): # autoestados del oscilador armónico cuántico
    pol_Herm = scipy.special.hermite(n)
    xi = np.sqrt(m*w_0)*x
    phi = (m*w_0/(np.pi))**(0.25)*(1/math.sqrt(2**n*np.math.factorial(n)))*pol_Herm(xi)*np.exp(-(xi**2)/2)
    if conj == True:
        return np.conj(phi)
    return phi

# %%
x = np.linspace(-10,10,500) # Estas x tienen unidades de posición
Unm = np.zeros([N,N],dtype=complex)
U_x = np.zeros(np.size(x),dtype=complex)

for i in tqdm(range(N)):
    for j in range(N):
        Unm[i][j] = scipy.integrate.simpson(autoest(j,x,False)*autoest(i,x,True)*U(x),x)
        U_x = U_x + autoest(j,x,False)*autoest(i,x,True)*Unm[i][j]

U_q = Qobj(Unm)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 145.20it/s]

# %%
plt.plot(x,U_x,label='Truncated series expansion')
plt.plot(x,U(x),label='Original')
plt.xlim([np.min(x),np.max(x)])
plt.ylim([0,np.max(U_x[(np.size(U_x)//2):])])
plt.title('Potential of the quantum system')
plt.xlabel('x')
plt.ylabel('U')
plt.legend()
plt.show()
# Out:
# c:\Users\rodri\anaconda3\envs\QuantumChaos\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# c:\Users\rodri\anaconda3\envs\QuantumChaos\lib\site-packages\matplotlib\transforms.py:2877: ComplexWarning: Casting complex values to real discards the imaginary part
#   vmin, vmax = map(float, [vmin, vmax])

# %% [markdown]
# Simulación de la dinámica cuántica

# %%
dt = 0.1 # Paso de tiempo
tf = 100 # Tiempo de medida (se asume que t0 = 0)
tvec = np.linspace(0,tf,int(tf/dt)+1) # Vector de instantes de tiempo

# %%
def check_state(psi):
    check = np.sum(np.diagonal(psi.full())[-5:])

    if check >= 1e-2:
        return sys.exit("Warning: add more phonons")

# %%
# Estado inicial:
psi0 = coherent(N,X_0*math.sqrt(0.5))

x_0 = expect(position(N),psi0)/math.sqrt(w_0*m) 
p_0 = expect(momentum(N),psi0)*math.sqrt(w_0*m)

# Estado para comparar:
# psi02 = coherent(N,math.sqrt(0.6))

# %%
def H1coeff(t,args):
    return f_0*m*np.cos(args['w']*t)

# %%
result = []
H0 = w_0*momentum(N)**2/2+U_q
H1 = position(N)/math.sqrt(w_0*m)
x_exp = position(N)/math.sqrt(w_0*m)
p_exp = momentum(N)*math.sqrt(w_0*m)
x2_exp = position(N)**2/(w_0*m)
p2_exp = momentum(N)**2*(w_0*m)
coll = math.sqrt(2*amort*m)*destroy(N)
options = Options(store_states=True,nsteps=5000)

for i in tqdm(range(n)):
    args = {'w': w[i]}
    H = [H0,[H1,H1coeff]]
    result.append(mesolve(H, psi0, tvec, [coll], [x_exp,p_exp,x2_exp,p2_exp],options=options,args=args))
    # result2 = mesolve(H, psi02, tvec, [], [position(N)/math.sqrt(w_0*m),momentum(N)*math.sqrt(w_0*m),position(N)**2/(w_0*m),momentum(N)**2*(w_0*m)],options=options)
# Out:
# 100%|██████████| 1/1 [02:05<00:00, 125.87s/it]

# %% [markdown]
# Wigner function evolution

# %%
Wigner = []
wig_xvec = np.linspace(-6,6,100)
wig_pvec = np.linspace(-6,6,100)

for i in tqdm(range(np.size(tvec))):   
    Wigner.append(wigner(result[rep].states[i], wig_xvec, wig_pvec))
# Out:
# 100%|██████████| 1001/1001 [00:45<00:00, 22.16it/s]

# %% [markdown]
# Amount of negativity

# %%
neg = []
#pos = []

for i in range(np.shape(Wigner)[0]):
    neg.append(100*np.sum(((Wigner[i]<0)*1)*np.abs(Wigner[i]))/np.sum(np.abs(Wigner[i])))
    #pos.append(100*np.sum(((Wigner[i]>=0)*1)*np.abs(Wigner[i]))/np.sum(np.abs(Wigner[i])))

# %%
fig1 = plt.figure()
plt.plot(tvec,neg)
plt.xlim([0,tf])
plt.ylim([0,np.max(neg)])
plt.title('Percentage of negativity of the Wigner Function')
plt.xlabel('t')
plt.ylabel('Amount of negativity (%)')
plt.show()

# %% [markdown]
# Probability density

# %%
np.shape(np.resize(autoest(j,x,False),[np.size(x),1])*np.resize(autoest(j,x,True),[1,np.size(x)]))
# Out:
# (500, 500)

# %%
np.shape(result[rep].states[i])
# Out:
# (30, 30)

# %%
prob = []
for j in range(N):
        xx = np.resize(autoest(j,x,False),[np.size(x),1])*np.resize(autoest(j,x,True),[1,np.size(x)])
for i in tqdm(range(np.size(tvec))):
    psi_x = 0
    for j in range(N):
        psi_x = psi_x + result[rep].states[i][j]*np.resize(autoest(j,x,False),[np.size(x),1])*np.resize(autoest(j,x,True),[1,np.size(x)])
    prob.append(np.abs(psi_x)**2)
# Out:
#   0%|          | 0/1001 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [151], line 6
#       4 psi_x = 0
#       5 for j in range(N):
# ----> 6     psi_x = psi_x + autoest(j,x,False)*result[rep].states[i][j]
#       7 prob.append(np.abs(psi_x)**2)
#
# ValueError: operands could not be broadcast together with shapes (500,) (1,30)

# %%
print(result[rep].states[i])
# Out:
# Quantum object: dims = [[30], [30]], shape = (30, 30), type = oper, isherm = True
# Qobj data =
# [[1.11089965e-02 2.35657404e-02 3.53486105e-02 4.32930295e-02
#   4.59191921e-02 4.35627706e-02 3.77264660e-02 3.02484664e-02
#   2.26863498e-02 1.60416718e-02 1.07610806e-02 6.88281027e-03
#   4.21484329e-03 2.47979633e-03 1.40591237e-03 7.70049918e-04
#   4.08380639e-04 2.10110106e-04 1.05055053e-04 5.11265399e-05
#   2.42514472e-05 1.12262388e-05 5.07725693e-06 2.24580425e-06
#   9.72454287e-07 4.12602020e-07 1.71575397e-07 7.02784574e-08
#   2.75020665e-08 1.26896903e-08]
#  [2.35657404e-02 4.99904844e-02 7.49857266e-02 9.18383841e-02
#   9.74093163e-02 9.24105914e-02 8.00299198e-02 6.41666872e-02
#   4.81250154e-02 3.40295248e-02 2.28276992e-02 1.46006455e-02
#   8.94103282e-03 5.26044240e-03 2.98239051e-03 1.63352256e-03
#   8.66306158e-04 4.45710841e-04 2.22855421e-04 1.08455769e-04
#   5.14450883e-05 2.38144487e-05 1.07704884e-05 4.76407025e-06
#   2.06288706e-06 8.75261058e-07 3.63966380e-07 1.49083121e-07
#   5.83406932e-08 2.69188983e-08]
#  [3.53486105e-02 7.49857266e-02 1.12478590e-01 1.37757576e-01
#   1.46113974e-01 1.38615887e-01 1.20044880e-01 9.62500308e-02
#   7.21875231e-02 5.10442871e-02 3.42415488e-02 2.19009682e-02
#   1.34115492e-02 7.89066360e-03 4.47358576e-03 2.45028384e-03
#   1.29945924e-03 6.68566262e-04 3.34283131e-04 1.62683654e-04
#   7.71676325e-05 3.57216731e-05 1.61557326e-05 7.14610537e-06
#   3.09433059e-06 1.31289159e-06 5.45949570e-07 2.23624682e-07
#   8.75110398e-08 4.03783474e-08]
#  [4.32930295e-02 9.18383841e-02 1.37757576e-01 1.68717885e-01
#   1.78952341e-01 1.69769097e-01 1.47024351e-01 1.17881732e-01
#   8.84112987e-02 6.25162289e-02 4.19371612e-02 2.68230985e-02
#   1.64257261e-02 9.66404978e-03 5.47900122e-03 3.00097256e-03
#   1.59150604e-03 8.18823101e-04 4.09411550e-04 1.99245971e-04
#   9.45106621e-05 4.37499359e-05 1.97866507e-05 8.75215591e-06
#   3.78976552e-06 1.60795724e-06 6.68648936e-07 2.73883182e-07
#   1.07178697e-07 4.94531739e-08]
#  [4.59191921e-02 9.74093163e-02 1.46113974e-01 1.78952341e-01
#   1.89807621e-01 1.80067319e-01 1.55942873e-01 1.25032458e-01
#   9.37743433e-02 6.63084741e-02 4.44810766e-02 2.84501922e-02
#   1.74221135e-02 1.02502727e-02 5.81135838e-03 3.18301207e-03
#   1.68804707e-03 8.68493050e-04 4.34246525e-04 2.11332265e-04
#   1.00243695e-04 4.64038146e-05 2.09869123e-05 9.28306319e-06
#   4.01965335e-06 1.70549620e-06 7.09209295e-07 2.90496983e-07
#   1.13680175e-07 5.24530119e-08]
#  [4.35627706e-02 9.24105914e-02 1.38615887e-01 1.69769097e-01
#   1.80067319e-01 1.70826858e-01 1.47940399e-01 1.18616204e-01
#   8.89621533e-02 6.29057419e-02 4.21984545e-02 2.69902222e-02
#   1.65280681e-02 9.72426251e-03 5.51313863e-03 3.01967039e-03
#   1.60142206e-03 8.23924851e-04 4.11962426e-04 2.00487390e-04
#   9.50995193e-05 4.40225238e-05 1.99099332e-05 8.80668700e-06
#   3.81337800e-06 1.61797576e-06 6.72815013e-07 2.75589636e-07
#   1.07846484e-07 4.97612963e-08]
#  [3.77264660e-02 8.00299198e-02 1.20044880e-01 1.47024351e-01
#   1.55942873e-01 1.47940399e-01 1.28120144e-01 1.02724646e-01
#   7.70434847e-02 5.44779705e-02 3.65449336e-02 2.33742181e-02
#   1.43137268e-02 8.42145837e-03 4.77451811e-03 2.61511127e-03
#   1.38687218e-03 7.13539852e-04 3.56769926e-04 1.73627173e-04
#   8.23585996e-05 3.81246240e-05 1.72425079e-05 7.62681467e-06
#   3.30248222e-06 1.40120811e-06 5.82674893e-07 2.38667626e-07
#   9.33977946e-08 4.30945467e-08]
#  [3.02484664e-02 6.41666872e-02 9.62500308e-02 1.17881732e-01
#   1.25032458e-01 1.18616204e-01 1.02724646e-01 8.23629496e-02
#   6.17722122e-02 4.36795501e-02 2.93011330e-02 1.87410676e-02
#   1.14765132e-02 6.75218826e-03 3.82813092e-03 2.09675366e-03
#   1.11197155e-03 5.72104641e-04 2.86052321e-04 1.39211442e-04
#   6.60337848e-05 3.05677031e-05 1.38247622e-05 6.11505588e-06
#   2.64787650e-06 1.12346586e-06 4.67179247e-07 1.91359818e-07
#   7.48848317e-08 3.45525063e-08]
#  [2.26863498e-02 4.81250154e-02 7.21875231e-02 8.84112987e-02
#   9.37743433e-02 8.89621533e-02 7.70434847e-02 6.17722122e-02
#   4.63291592e-02 3.27596626e-02 2.19758498e-02 1.40558007e-02
#   8.60738493e-03 5.06414120e-03 2.87109819e-03 1.57256524e-03
#   8.33978660e-04 4.29078481e-04 2.14539240e-04 1.04408581e-04
#   4.95253386e-05 2.29257773e-05 1.03685717e-05 4.58629191e-06
#   1.98590737e-06 8.42599395e-07 3.50384435e-07 1.43519864e-07
#   5.61636238e-08 2.59143797e-08]
#  [1.60416718e-02 3.40295248e-02 5.10442871e-02 6.25162289e-02
#   6.63084741e-02 6.29057419e-02 5.44779705e-02 4.36795501e-02
#   3.27596626e-02 2.31645796e-02 1.55392724e-02 9.93895201e-03
#   6.08634025e-03 3.58088858e-03 2.03017300e-03 1.11197155e-03
#   5.89711966e-04 3.03404303e-04 1.51702152e-04 7.38280159e-05
#   3.50197028e-05 1.62109726e-05 7.33168734e-06 3.24299811e-06
#   1.40424857e-06 5.95807746e-07 2.47759210e-07 1.01483869e-07
#   3.97136792e-08 1.83242336e-08]
#  [1.07610806e-02 2.28276992e-02 3.42415488e-02 4.19371612e-02
#   4.44810766e-02 4.21984545e-02 3.65449336e-02 2.93011330e-02
#   2.19758498e-02 1.55392724e-02 1.04240608e-02 6.66725170e-03
#   4.08284116e-03 2.40213309e-03 1.36188145e-03 7.45933190e-04
#   3.95590813e-04 2.03529794e-04 1.01764897e-04 4.95253387e-05
#   2.34919308e-05 1.08746510e-05 4.91824539e-06 2.17546927e-06
#   9.41998579e-07 3.99679986e-07 1.66201931e-07 6.80774488e-08
#   2.66407459e-08 1.22922696e-08]
#  [6.88281027e-03 1.46006455e-02 2.19009682e-02 2.68230985e-02
#   2.84501922e-02 2.69902222e-02 2.33742181e-02 1.87410676e-02
#   1.40558007e-02 9.93895201e-03 6.66725170e-03 4.26438851e-03
#   2.61139398e-03 1.53640948e-03 8.71062302e-04 4.77100472e-04
#   2.53020734e-04 1.30178094e-04 6.50890469e-05 3.16765131e-05
#   1.50254894e-05 6.95545015e-06 3.14572032e-06 1.39143482e-06
#   6.02504315e-07 2.55636178e-07 1.06303112e-07 4.35424826e-08
#   1.70394783e-08 7.86216205e-09]
#  [4.21484329e-03 8.94103282e-03 1.34115492e-02 1.64257261e-02
#   1.74221135e-02 1.65280681e-02 1.43137268e-02 1.14765132e-02
#   8.60738493e-03 6.08634025e-03 4.08284116e-03 2.61139398e-03
#   1.59914569e-03 9.40854818e-04 5.33414543e-04 2.92163178e-04
#   1.54942923e-04 7.97174763e-05 3.98587382e-05 1.93978235e-05
#   9.20119555e-06 4.25932595e-06 1.92635241e-06 8.52076329e-07
#   3.68957035e-07 1.56544549e-07 6.50970957e-08 2.66642161e-08
#   1.04345069e-08 4.81457132e-09]
#  [2.47979633e-03 5.26044240e-03 7.89066360e-03 9.66404978e-03
#   1.02502727e-02 9.72426251e-03 8.42145837e-03 6.75218826e-03
#   5.06414120e-03 3.58088858e-03 2.40213309e-03 1.53640948e-03
#   9.40854818e-04 5.53550432e-04 3.13833596e-04 1.71893740e-04
#   9.11604218e-05 4.69016501e-05 2.34508250e-05 1.14126785e-05
#   5.41350873e-06 2.50596763e-06 1.13336637e-06 5.01317749e-07
#   2.17075283e-07 9.21027359e-08 3.82997724e-08 1.56878490e-08
#   6.13912547e-09 2.83264536e-09]
#  [1.40591237e-03 2.98239051e-03 4.47358576e-03 5.47900122e-03
#   5.81135838e-03 5.51313863e-03 4.77451811e-03 3.82813092e-03
#   2.87109819e-03 2.03017300e-03 1.36188145e-03 8.71062302e-04
#   5.33414543e-04 3.13833596e-04 1.77926925e-04 9.74545902e-05
#   5.16831012e-05 2.65907362e-05 1.32953681e-05 6.47038052e-06
#   3.06917096e-06 1.42075010e-06 6.42558334e-07 2.84220448e-07
#   1.23070118e-07 5.22173430e-08 2.17139300e-08 8.89417439e-09
#   3.48055698e-09 1.60595897e-09]
#  [7.70049918e-04 1.63352256e-03 2.45028384e-03 3.00097256e-03
#   3.18301207e-03 3.01967039e-03 2.61511127e-03 2.09675366e-03
#   1.57256524e-03 1.11197155e-03 7.45933190e-04 4.77100472e-04
#   2.92163178e-04 1.71893740e-04 9.74545902e-05 5.33780774e-05
#   2.83080004e-05 1.45643460e-05 7.28217302e-06 3.54397337e-06
#   1.68105417e-06 7.78176880e-07 3.51943694e-07 1.55673951e-07
#   6.74082796e-08 2.86006167e-08 1.18932092e-08 4.87153994e-09
#   1.90637957e-09 8.79619953e-10]
#  [4.08380639e-04 8.66306158e-04 1.29945924e-03 1.59150604e-03
#   1.68804707e-03 1.60142206e-03 1.38687218e-03 1.11197155e-03
#   8.33978660e-04 5.89711966e-04 3.95590813e-04 2.53020734e-04
#   1.54942923e-04 9.11604218e-05 5.16831012e-05 2.83080004e-05
#   1.50125843e-05 7.72391088e-06 3.86195544e-06 1.87947570e-06
#   8.91513601e-07 4.12690612e-07 1.86646330e-07 8.25585797e-08
#   3.57486387e-08 1.51677675e-08 6.30732668e-09 2.58352420e-09
#   1.01101044e-09 4.66488925e-10]
#  [2.10110106e-04 4.45710841e-04 6.68566262e-04 8.18823101e-04
#   8.68493050e-04 8.23924851e-04 7.13539852e-04 5.72104641e-04
#   4.29078481e-04 3.03404303e-04 2.03529794e-04 1.30178094e-04
#   7.97174763e-05 4.69016501e-05 2.65907362e-05 1.45643460e-05
#   7.72391088e-06 3.97391936e-06 1.98695968e-06 9.66982270e-07
#   4.58679964e-07 2.12327568e-07 9.60287444e-08 4.24760389e-08
#   1.83925229e-08 7.80375200e-09 3.24509281e-09 1.32921223e-09
#   5.20160581e-10 2.40006572e-10]
#  [1.05055053e-04 2.22855421e-04 3.34283131e-04 4.09411550e-04
#   4.34246525e-04 4.11962426e-04 3.56769926e-04 2.86052321e-04
#   2.14539240e-04 1.51702152e-04 1.01764897e-04 6.50890469e-05
#   3.98587382e-05 2.34508250e-05 1.32953681e-05 7.28217302e-06
#   3.86195544e-06 1.98695968e-06 9.93479841e-07 4.83491135e-07
#   2.29339982e-07 1.06163784e-07 4.80143722e-08 2.12380194e-08
#   9.19626143e-09 3.90187600e-09 1.62254640e-09 6.64606117e-10
#   2.60080291e-10 1.20003286e-10]
#  [5.11265399e-05 1.08455769e-04 1.62683654e-04 1.99245971e-04
#   2.11332265e-04 2.00487390e-04 1.73627173e-04 1.39211442e-04
#   1.04408581e-04 7.38280159e-05 4.95253387e-05 3.16765131e-05
#   1.93978235e-05 1.14126785e-05 6.47038052e-06 3.54397337e-06
#   1.87947570e-06 9.66982270e-07 4.83491135e-07 2.35297857e-07
#   1.11611573e-07 5.16661197e-08 2.33668791e-08 1.03357851e-08
#   4.47549180e-09 1.89890361e-09 7.89635350e-10 3.23440046e-10
#   1.26571783e-10 5.84013108e-11]
#  [2.42514472e-05 5.14450883e-05 7.71676325e-05 9.45106621e-05
#   1.00243695e-04 9.50995193e-05 8.23585996e-05 6.60337848e-05
#   4.95253386e-05 3.50197028e-05 2.34919308e-05 1.50254894e-05
#   9.20119555e-06 5.41350873e-06 3.06917096e-06 1.68105417e-06
#   8.91513601e-07 4.58679964e-07 2.29339982e-07 1.11611573e-07
#   5.29420177e-08 2.45073924e-08 1.10838839e-08 4.90269333e-09
#   2.12291216e-09 9.00729068e-10 3.74556933e-10 1.53421085e-10
#   6.00382682e-11 2.77021740e-11]
#  [1.12262388e-05 2.38144487e-05 3.57216731e-05 4.37499359e-05
#   4.64038146e-05 4.40225238e-05 3.81246240e-05 3.05677031e-05
#   2.29257773e-05 1.62109726e-05 1.08746510e-05 6.95545015e-06
#   4.25932595e-06 2.50596763e-06 1.42075010e-06 7.78176880e-07
#   4.12690612e-07 2.12327568e-07 1.06163784e-07 5.16661197e-08
#   2.45073924e-08 1.13447184e-08 5.13084134e-09 2.26950605e-09
#   9.82717386e-10 4.16956544e-10 1.73386171e-10 7.10201630e-11
#   2.77923181e-11 1.28236149e-11]
#  [5.07725693e-06 1.07704884e-05 1.61557326e-05 1.97866507e-05
#   2.09869123e-05 1.99099332e-05 1.72425079e-05 1.38247622e-05
#   1.03685717e-05 7.33168734e-06 4.91824539e-06 3.14572032e-06
#   1.92635241e-06 1.13336637e-06 6.42558334e-07 3.51943694e-07
#   1.86646330e-07 9.60287444e-08 4.80143722e-08 2.33668791e-08
#   1.10838839e-08 5.13084134e-09 2.32051003e-09 1.02642261e-09
#   4.44450608e-10 1.88575670e-10 7.84168371e-11 3.21200734e-11
#   1.25695473e-11 5.79969738e-12]
#  [2.24580425e-06 4.76407025e-06 7.14610537e-06 8.75215591e-06
#   9.28306319e-06 8.80668700e-06 7.62681467e-06 6.11505588e-06
#   4.58629191e-06 3.24299811e-06 2.17546927e-06 1.39143482e-06
#   8.52076329e-07 5.01317749e-07 2.84220448e-07 1.55673951e-07
#   8.25585797e-08 4.24760389e-08 2.12380194e-08 1.03357851e-08
#   4.90269333e-09 2.26950605e-09 1.02642261e-09 4.54013711e-10
#   1.96592191e-10 8.34119776e-11 3.46858291e-11 1.42075531e-11
#   5.55984132e-12 2.56535866e-12]
#  [9.72454287e-07 2.06288706e-06 3.09433059e-06 3.78976552e-06
#   4.01965335e-06 3.81337800e-06 3.30248222e-06 2.64787650e-06
#   1.98590737e-06 1.40424857e-06 9.41998579e-07 6.02504315e-07
#   3.68957035e-07 2.17075283e-07 1.23070118e-07 6.74082796e-08
#   3.57486387e-08 1.83925229e-08 9.19626143e-09 4.47549180e-09
#   2.12291216e-09 9.82717386e-10 4.44450608e-10 1.96592191e-10
#   8.51262611e-11 3.61181680e-11 1.50192891e-11 6.15200364e-12
#   2.40746339e-12 1.11082434e-12]
#  [4.12602020e-07 8.75261058e-07 1.31289159e-06 1.60795724e-06
#   1.70549620e-06 1.61797576e-06 1.40120811e-06 1.12346586e-06
#   8.42599395e-07 5.95807746e-07 3.99679986e-07 2.55636178e-07
#   1.56544549e-07 9.21027359e-08 5.22173430e-08 2.86006167e-08
#   1.51677675e-08 7.80375200e-09 3.90187600e-09 1.89890361e-09
#   9.00729068e-10 4.16956544e-10 1.88575670e-10 8.34119776e-11
#   3.61181680e-11 1.53245548e-11 6.37252474e-12 2.61022977e-12
#   1.02146113e-12 0.00000000e+00]
#  [1.71575397e-07 3.63966380e-07 5.45949570e-07 6.68648936e-07
#   7.09209295e-07 6.72815013e-07 5.82674893e-07 4.67179247e-07
#   3.50384435e-07 2.47759210e-07 1.66201931e-07 1.06303112e-07
#   6.50970957e-08 3.82997724e-08 2.17139300e-08 1.18932092e-08
#   6.30732668e-09 3.24509281e-09 1.62254640e-09 7.89635350e-10
#   3.74556933e-10 1.73386171e-10 7.84168371e-11 3.46858291e-11
#   1.50192891e-11 6.37252474e-12 2.64993483e-12 1.08543145e-12
#   0.00000000e+00 0.00000000e+00]
#  [7.02784574e-08 1.49083121e-07 2.23624682e-07 2.73883182e-07
#   2.90496983e-07 2.75589636e-07 2.38667626e-07 1.91359818e-07
#   1.43519864e-07 1.01483869e-07 6.80774488e-08 4.35424826e-08
#   2.66642161e-08 1.56878490e-08 8.89417439e-09 4.87153994e-09
#   2.58352420e-09 1.32921223e-09 6.64606117e-10 3.23440046e-10
#   1.53421085e-10 7.10201630e-11 3.21200734e-11 1.42075531e-11
#   6.15200364e-12 2.61022977e-12 1.08543145e-12 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [2.75020665e-08 5.83406932e-08 8.75110398e-08 1.07178697e-07
#   1.13680175e-07 1.07846484e-07 9.33977946e-08 7.48848317e-08
#   5.61636238e-08 3.97136792e-08 2.66407459e-08 1.70394783e-08
#   1.04345069e-08 6.13912547e-09 3.48055698e-09 1.90637957e-09
#   1.01101044e-09 5.20160581e-10 2.60080291e-10 1.26571783e-10
#   6.00382682e-11 2.77923181e-11 1.25695473e-11 5.55984132e-12
#   2.40746339e-12 1.02146113e-12 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.26896903e-08 2.69188983e-08 4.03783474e-08 4.94531739e-08
#   5.24530119e-08 4.97612963e-08 4.30945467e-08 3.45525063e-08
#   2.59143797e-08 1.83242336e-08 1.22922696e-08 7.86216205e-09
#   4.81457132e-09 2.83264536e-09 1.60595897e-09 8.79619953e-10
#   4.66488925e-10 2.40006572e-10 1.20003286e-10 5.84013108e-11
#   2.77021740e-11 1.28236149e-11 5.79969738e-12 2.56535866e-12
#   1.11082434e-12 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %% [markdown]
# Save animations and figures

# %%
def update_Wigner(num,Wigner):
    plt.cla()
    wmap = wigner_cmap(Wigner[num])
    nrm = mpl.colors.Normalize(-Wigner[num].max(), Wigner[num].max())
    plt.contourf(wig_xvec, wig_pvec, Wigner[num], 100, cmap=cm.RdBu, norm=nrm)
    plt.xlim([np.min(wig_xvec),np.max(wig_xvec)])
    plt.ylim([np.min(wig_pvec),np.max(wig_pvec)])
    plt.title('Evolution of the Wigner function (t = '+str(format(tvec[num],'.3f'))+' s)')
    plt.axis('equal')
    plt.xlabel('x')
    plt.ylabel('p')

# %%
imW = plt.figure()
wmap = wigner_cmap(Wigner[0])
nrm = mpl.colors.Normalize(-Wigner[0].max(), Wigner[0].max())
figW = plt.contourf(wig_xvec, wig_pvec, Wigner[0], 100, cmap=cm.RdBu, norm=nrm)
plt.colorbar(cm.ScalarMappable(norm=nrm, cmap=cm.RdBu))
animW = animation.FuncAnimation(imW, update_Wigner, range(np.size(tvec)), fargs = (Wigner, ), interval = 25)
animW.save('WIGNER (ω = '+str(format(w[rep],'.1f'))+' s⁻¹).gif')
animW.save('WIGNER (ω = '+str(format(w[rep],'.1f'))+' s⁻¹).mp4')

# %%
def update_prob(num,prob):
    ax1.cla()
    ax2.cla()
    ax1.plot(x, prob[num][0], label = '$|Ψ(x)|^2$', color = 'purple')
    ax2.plot(x,U(x), alpha = 0.5, label = 'U(x)')
    ax1.set_xlim([np.min(x),np.max(x)])
    ax1.set_ylim([0,1.5])
    ax2.set_ylim([0,100])
    ax1.set_title('Evolution of probability density (t = '+str(format(tvec[num],'.3f'))+' s)')
    ax1.set_xlabel('x')
    ax1.set_ylabel('$|Ψ(x)|^2$')
    ax2.set_ylabel('U(x)')
    ax2.legend()

# %%
imP = plt.figure()
ax1 = plt.subplot()
ax2 = ax1.twinx()
ax1.plot(x, prob[0][0], label = '$|Ψ(x)|^2$', color = 'purple')
ax2.plot(x,U(x), alpha = 0.5, label = 'U(x)')
animP = animation.FuncAnimation(imP, update_prob, range(np.size(tvec)), fargs = (prob, ), interval = 25)
animP.save('prob (ω = '+str(format(w[rep],'.1f'))+' s⁻¹).gif')
animP.save('prob (ω = '+str(format(w[rep],'.1f'))+' s⁻¹).mp4')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [133], line 4
#       2 ax1 = plt.subplot()
#       3 ax2 = ax1.twinx()
# ----> 4 ax1.plot(x, prob[0][0], label = '$|Ψ(x)|^2$', color = 'purple')
#       5 ax2.plot(x,U(x), alpha = 0.5, label = 'U(x)')
#       6 animP = animation.FuncAnimation(imP, update_prob, range(np.size(tvec)), fargs = (prob, ), interval = 25)
#
# IndexError: list index out of range

# %%
fig1.savefig('Negativity (ω = '+str(format(w[rep],'.1f'))+' s⁻¹).png')
